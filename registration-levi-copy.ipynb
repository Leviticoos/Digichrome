# %%
import numpy as np
import matplotlib.pyplot as plt

from skimage.color import rgb2gray
from skimage.transform import warp
from skimage.registration import optical_flow_tvl1, optical_flow_ilk
from skimage.io import imread
from skimage.transform import rotate, resize

# %%
filter_img = imread('Filters-Round-1/RGB_0.1mm_1a.tif')
film_img = imread('Fruit-Bowl/Rhine_1_RGB_0.1.png')
filter_img = np.uint8(filter_img >> 8)
# Out:
# <tifffile.TiffPages @252150920> invalid offset to first page 252150920
# <tifffile.TiffPages @252150920> invalid offset to first page 252150920
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 filter_img = imread('Filters-Round-1/RGB_0.1mm_1a.tif')
# ----> 2 film_img = imread('Fruit-Bowl/Rhine_1_RGB_0.1.png')
#       3 filter_img = np.uint8(filter_img >> 8)
#
# File ~/.local/lib/python3.8/site-packages/skimage/io/_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#      56     return img
#
# File ~/.local/lib/python3.8/site-packages/skimage/io/manage_plugins.py:207, in call_plugin(kind, *args, **kwargs)
#     203     except IndexError:
#     204         raise RuntimeError('Could not find the plugin "%s" for %s.' %
#     205                            (plugin, kind))
# --> 207 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/skimage/io/_plugins/imageio_plugin.py:10, in imread(*args, **kwargs)
#       8 @wraps(imageio_imread)
#       9 def imread(*args, **kwargs):
# ---> 10     return np.asarray(imageio_imread(*args, **kwargs))
#
# File ~/.local/lib/python3.8/site-packages/imageio/__init__.py:97, in imread(uri, format, **kwargs)
#      68 """imread(uri, format=None, **kwargs)
#      69
#      70 Reads an image from the specified file. Returns a numpy array, which
#    (...)
#      86     to see what arguments are available for a particular format.
#      87 """
#      89 warnings.warn(
#      90     "Starting with ImageIO v3 the behavior of this function will switch to that of"
#      91     " iio.v3.imread. To keep the current behavior (and make this warning dissapear)"
#    (...)
#      94     stacklevel=2,
#      95 )
# ---> 97 return imread_v2(uri, format=format, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/imageio/v2.py:201, in imread(uri, format, **kwargs)
#     198 imopen_args["legacy_mode"] = True
#     200 with imopen(uri, "ri", **imopen_args) as file:
# --> 201     return file.read(index=0, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/imageio/core/legacy_plugin_wrapper.py:146, in LegacyPlugin.read(self, index, **kwargs)
#     143     return img
#     145 reader = self.legacy_get_reader(**kwargs)
# --> 146 return reader.get_data(index)
#
# File ~/.local/lib/python3.8/site-packages/imageio/core/format.py:434, in Format.Reader.get_data(self, index, **kwargs)
#     432 self._BaseReaderWriter_last_index = index
#     433 try:
# --> 434     im, meta = self._get_data(index, **kwargs)
#     435 except StopIteration:
#     436     raise IndexError(index)
#
# File ~/.local/lib/python3.8/site-packages/imageio/plugins/tifffile.py:444, in TiffFormat.Reader._get_data(self, index)
#     441 else:
#     442     # Read as 2D image
#     443     if index < 0 or index >= self._get_length():
# --> 444         raise IndexError("Index out of range while reading from tiff file")
#     445     im = self._tf.pages[index].asarray()
#     446 # Return array and empty meta data
#
# IndexError: Index out of range while reading from tiff file

# %%
plt.imshow(filter_img)

# %%
plt.figure(figsize=(12, 12))
plt.imshow(film_img/255**2)

# %%
rot_film_img = rotate(film_img, 89, mode='wrap')
crop_film_img = rot_film_img[500:5250,400:7500,:]

plt.figure(figsize=(6,6))
plt.imshow(crop_film_img)

# %%
plt.imshow(filter_img)

# %%
resize_film_img = resize(crop_film_img, output_shape=filter_img.shape)

# %%
filterR = filter_img[:,:,0]
filterG = filter_img[:,:,1]
filterB = filter_img[:,:,2]

film = rgb2gray(resize_film_img)

fig, axs = plt.subplots(2,3, figsize=(10, 5))
axs[0,0].imshow(filterR, cmap='Greys')
axs[0,1].imshow(filterG, cmap='Greys')
axs[0,2].imshow(filterB, cmap='Greys')
axs[1,0].imshow(film, cmap='Greys')
axs[1,1].imshow(film, cmap='Greys')
axs[1,2].imshow(film, cmap='Greys')
plt.show()

# %%
fig, axs = plt.subplots(1,3, figsize=(10, 5))
R = filterR * film
G = filterG * film
B = filterB * film
axs[0].imshow(R, cmap='Greys')
axs[1].imshow(G, cmap='Greys')
axs[2].imshow(B, cmap='Greys')
plt.show()

# %%
R_new = np.expand_dims(R, 2)
G_new = np.expand_dims(G, 2)
B_new = np.expand_dims(B, 2)
temp = np.append(R_new, G_new, axis=2)
reconst_img = np.append(temp, B_new, axis=2)

# %%
plt.imshow(reconst_img/255)

# %%
v, u = optical_flow_ilk(filterR, film)
nr, nc = film.shape
row_coords, col_coords = np.meshgrid(np.arange(nr), np.arange(nc), indexing='ij')
warp_film = warp(film, np.array([row_coords + v, col_coords + u]), mode='edge')

# %%
plt.imshow(filterR, cmap='Greys')

# %%
plt.imshow(film, cmap='Greys')

# %%
plt.imshow(warp_film, cmap='Greys')
