# %%
import numpy as np
import matplotlib.pyplot as plt
import lenses as ln
#New, for VS code!
# %matplotlib widget

from importlib import reload  # Python 3.4+
ln = reload(ln)

# %%
ln.rayTracePlot(ln.opticalSystem([25,25,50], [0,100,100,100,1000]), ln.imageRays(9999,000,2,5))
# Out:
# [0.04, 0.04, 0.02]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
